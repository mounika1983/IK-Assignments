# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas as pd
data = {

    'Category': ['Fruit', 'Vegetable', 'Fruit', 'Vegetable', 'Fruit', 'Vegetable'],

    'Name': ['Apple', 'Carrot', 'Banana', 'Potato', 'Grape', 'Onion'],

    'Price': [2, 1, 1.5, 0.5, 3, 1],

    'Quantity': [10, 20, 15, 30, 5, 40]

}



df = pd.DataFrame(data)



fruits = df[df['Category'] == 'Fruit']

total_fruit_value = fruits['Price'].sum() * fruits['Quantity'].sum()

print(total_fruit_value)
# Out:
# 195.0

# %%
gas = pd.read_csv('gas_prices.csv', index_col = 'Year')

# %%
import pandas as pd



data = {

    'Name': ['Alice', 'Bob', 'Charlie', 'David'],

    'Age': [25, 30, 35, 40],

    'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']

}



df = pd.DataFrame(data)



result = df[df['Age'] >= 30].sort_values(by='Age', ascending=False).iloc[0]['City']

print(result)
# Out:
# Chicago

# %%
import pandas as pd



data = {

    'Product': ['A', 'B', 'C', 'A', 'B', 'C'],

    'Price': [100, 200, 300, 150, 250, 350],

    'Quantity': [10, 5, 7, 12, 8, 5]

}



df = pd.DataFrame(data)



total_revenue = (df['Price'] * df['Quantity']).sum()

average_price = df['Price'].mean()

print(total_revenue, average_price)
# Out:
# 9650 225.0

# %%
gas.head()
# Out:
#       Australia  Canada  France  Germany  Italy  Japan  Mexico  South Korea  \
# Year
# 1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00         2.05
# 1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30         2.49
# 1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50         2.65
# 1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56         2.88
# 1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48         2.87
#
#         UK   USA
# Year
# 1990  2.82  1.16
# 1991  3.01  1.14
# 1992  3.06  1.13
# 1993  2.84  1.11
# 1994  2.99  1.11

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 1990 to 2008
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Australia    18 non-null     float64
#  1   Canada       19 non-null     float64
#  2   France       19 non-null     float64
#  3   Germany      19 non-null     float64
#  4   Italy        19 non-null     float64
#  5   Japan        19 non-null     float64
#  6   Mexico       19 non-null     float64
#  7   South Korea  19 non-null     float64
#  8   UK           19 non-null     float64
#  9   USA          19 non-null     float64
# dtypes: float64(10)
# memory usage: 1.6 KB

# %%
gas.describe()
# Out:
#        Australia     Canada     France    Germany      Italy      Japan  \
# count  18.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean    2.348889   2.086842   4.407895   4.224737   4.645789   3.820526
# std     0.845931   0.786618   1.167531   1.425749   1.146610   0.696615
# min     1.630000   1.380000   3.410000   2.650000   3.570000   2.820000
# 25%     1.780000   1.590000   3.605000   3.370000   3.805000   3.270000
# 50%     1.955000   1.730000   3.870000   3.530000   4.390000   3.640000
# 75%     2.587500   2.180000   4.700000   4.915000   4.940000   4.320000
# max     4.450000   4.080000   7.510000   7.750000   7.630000   5.740000
#
#           Mexico  South Korea         UK        USA
# count  19.000000    19.000000  19.000000  19.000000
# mean    1.781579     3.835789   4.392632   1.592105
# std     0.462148     1.226170   1.455170   0.663355
# min     1.000000     2.050000   2.820000   1.060000
# 25%     1.475000     2.910000   3.135000   1.145000
# ...

# %%
gas_copy = gas.copy()

# %%
gas_copy.fillna(0,inplace = True)

# %%
gas_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 1990 to 2008
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Australia    19 non-null     float64
#  1   Canada       19 non-null     float64
#  2   France       19 non-null     float64
#  3   Germany      19 non-null     float64
#  4   Italy        19 non-null     float64
#  5   Japan        19 non-null     float64
#  6   Mexico       19 non-null     float64
#  7   South Korea  19 non-null     float64
#  8   UK           19 non-null     float64
#  9   USA          19 non-null     float64
# dtypes: float64(10)
# memory usage: 1.6 KB

# %%
plt.figure(figsize = (5,15))

# %%
plt.plot(gas_copy.index,gas_copy['Australia'], label = 'Aus')
plt.plot(gas_copy.index,gas_copy['Canada'], label = 'Can')
plt.legend()
plt.title('Gas Price Change from 1990 to 2008 (in USD)')
plt.xlabel('Year')
plt.ylabel('USD')
# Out:
# Text(0, 0.5, 'USD')

# %%
plt.scatter(gas_copy.USA,gas_copy.UK, marker = 'X', s = 5, color = 'green')
plt.xlabel('USA')
plt.ylabel('UK')
plt.show()

# %%
plt.plot(gas_copy.index,gas_copy['Australia'], label = 'Aus')
plt.legend()
plt.title('Gas Price Change from 1990 to 2008 (in USD)')
plt.xlabel('Year')
plt.ylabel('USD')
# Out:
# Text(0, 0.5, 'USD')

# %% [markdown]
# Gas Price Change Over Time (in USD)

# %%
plt.figure(figsize = (8,15))

# %%
plt.plot(gas.index, gas.USA, 'b.-', label = 'United States')
plt.plot(gas.index, gas.Canada, 'r.-', label='Canada')
plt.plot(gas.index, gas['South Korea'], 'g.-', label = 'South Korea')
plt.plot(gas.index, gas.Australia, 'y.-', label = 'Australia')
plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})
plt.xlabel('Year')
plt.ylabel('US Dollars')
plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300) # dpi - dots per inch - measure of dot density
plt.show()
